# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm, colors
from mpl_toolkits.mplot3d import axes3d
import torch
import torch.nn as nn
# %matplotlib notebook

# %% [markdown]
# ## 3D sphere

# %%
from ..distributions.AngularCentralGauss_torch import AngularCentralGaussian
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In [20], line 1
# ----> 1 from ..distributions.AngularCentralGauss_torch import AngularCentralGaussian
#
# ImportError: attempted relative import with no known parent package

# %%
ACG = AngularCentralGaussian(p=3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [11], line 1
# ----> 1 ACG = AngularCentralGaussian(p=3)
#
# NameError: name 'AngularCentralGaussian' is not defined

# %%
u = np.linspace(0, np.pi, 30)
v = np.linspace(0, 2 * np.pi, 30)

# ro = 1
# x = ro * np.outer(np.sin(u), np.sin(v))
# y = ro * np.outer(np.sin(u), np.cos(v))
# z = ro * np.outer(np.cos(u), np.ones_like(v))


ui = np.linspace(0, 2 * np.pi, 100)
vi = np.linspace(0, np.pi, 100)

ri = 10
x_inner = ri * np.outer(np.cos(ui), np.sin(vi))
y_inner = ri * np.outer(np.sin(ui), np.sin(vi))
z_inner = ri * np.outer(np.ones(np.size(ui)), np.cos(vi))


fig = plt.figure()
ax = plt.axes(projection='3d')

z1 = z_inner * np.cos(0.5*x_inner)

N = z1 / z1.max() 
ax.plot_surface(x_inner, y_inner, z_inner,rstride=1, cstride=1,  linewidth=0, facecolors=cm.viridis(N),antialiased=False, shade=False)
#surf = ax.plot_surface(x, y, z, rstride=1, cstride=1, facecolors=cm.jet(N), linewidth=0, antialiased=False, shade=False)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## 2D Circle plot
